# %%
import pandas as pd
import numpy as np

# %%
product_details = pd.read_clipboard()

# %%
product_details
# Out:
#   Product Id            Description
# 0       P123     Nike Running Shoes
# 1       P234           Dove Shampoo
# 2       P345  Pepsi 16OZ. Diet Coke
# 3       P999  Good furniture chairs
# 4       P567         Confort sheets

# %%
brand_details = pd.read_clipboard()
brand_details
# Out:
#   Product Id Brand Name
# 0       P123       Nike
# 1       P234       Dove
# 2       P345      Pepsi
# 3       P700       Coke

# %%
df1 = pd.merge(product_details, brand_details, on="Product Id") # this like an inner join
df1
# Out:
#   Product Id            Description Brand Name
# 0       P123     Nike Running Shoes       Nike
# 1       P234           Dove Shampoo       Dove
# 2       P345  Pepsi 16OZ. Diet Coke      Pepsi

# %%
df1 =pd.merge(product_details, brand_details, on="Product Id", how='left') # left  join
df1
# Out:
#   Product Id            Description Brand Name
# 0       P123     Nike Running Shoes       Nike
# 1       P234           Dove Shampoo       Dove
# 2       P345  Pepsi 16OZ. Diet Coke      Pepsi
# 3       P999  Good furniture chairs        NaN
# 4       P567         Confort sheets        NaN

# %%
df1 =pd.merge(product_details, brand_details, on="Product Id", how='right') # Right  join
df1
# Out:
#   Product Id            Description Brand Name
# 0       P123     Nike Running Shoes       Nike
# 1       P234           Dove Shampoo       Dove
# 2       P345  Pepsi 16OZ. Diet Coke      Pepsi
# 3       P700                    NaN       Coke

# %%
df1 =pd.merge(product_details, brand_details, on="Product Id", how='outer') # Outer  join
df1
# Out:
#   Product Id            Description Brand Name
# 0       P123     Nike Running Shoes       Nike
# 1       P234           Dove Shampoo       Dove
# 2       P345  Pepsi 16OZ. Diet Coke      Pepsi
# 3       P999  Good furniture chairs        NaN
# 4       P567         Confort sheets        NaN
# 5       P700                    NaN       Coke

# %%
product_order = pd.read_clipboard()
product_order
# Out:
#    Order No. Product Id
# 0          1       P123
# 1          1       P999
# 2          2       P234
# 3          2       P345

# %%
order_details = pd.read_clipboard()
order_details
# Out:
#    Order No.  Order Amt
# 0          1     100.00
# 1          2      56.99

# %%
df1 = pd.merge(product_order, order_details, on ='Order No.')
df2  = pd.merge(df1, product_details, on ="Product Id", suffixes=("_right", "_left"))
df2
# Out:
#    Order No. Product Id  Order Amt            Description
# 0          1       P123     100.00     Nike Running Shoes
# 1          1       P999     100.00  Good furniture chairs
# 2          2       P234      56.99           Dove Shampoo
# 3          2       P345      56.99  Pepsi 16OZ. Diet Coke

# %%
df2 = product_details.join(brand_details, lsuffix="_Product", rsuffix="_Brand" )  # uses Join instaed of Merge
df2
# Out:
#   Product Id_Product            Description Product Id_Brand Brand Name
# 0               P123     Nike Running Shoes             P123       Nike
# 1               P234           Dove Shampoo             P234       Dove
# 2               P345  Pepsi 16OZ. Diet Coke             P345      Pepsi
# 3               P999  Good furniture chairs             P700       Coke
# 4               P567         Confort sheets              NaN        NaN

# %%
brand_details
# Out:
#   Product Id Brand Name
# 0       P123       Nike
# 1       P234       Dove
# 2       P345      Pepsi
# 3       P700       Coke

# %%
pd.concat([product_details,brand_details])  # concatenating two Dataframe
# Out:
#   Brand Name            Description Product Id
# 0        NaN     Nike Running Shoes       P123
# 1        NaN           Dove Shampoo       P234
# 2        NaN  Pepsi 16OZ. Diet Coke       P345
# 3        NaN  Good furniture chairs       P999
# 4        NaN         Confort sheets       P567
# 0       Nike                    NaN       P123
# 1       Dove                    NaN       P234
# 2      Pepsi                    NaN       P345
# 3       Coke                    NaN       P700

# %%
pd.concat([product_details,brand_details], axis=0)  # concatenating two Dataframe on axis=0
# Out:
#   Brand Name            Description Product Id
# 0        NaN     Nike Running Shoes       P123
# 1        NaN           Dove Shampoo       P234
# 2        NaN  Pepsi 16OZ. Diet Coke       P345
# 3        NaN  Good furniture chairs       P999
# 4        NaN         Confort sheets       P567
# 0       Nike                    NaN       P123
# 1       Dove                    NaN       P234
# 2      Pepsi                    NaN       P345
# 3       Coke                    NaN       P700

# %%
pd.concat([product_details,brand_details], ignore_index=True) # index will be a continous series
# Out:
#   Brand Name            Description Product Id
# 0        NaN     Nike Running Shoes       P123
# 1        NaN           Dove Shampoo       P234
# 2        NaN  Pepsi 16OZ. Diet Coke       P345
# 3        NaN  Good furniture chairs       P999
# 4        NaN         Confort sheets       P567
# 5       Nike                    NaN       P123
# 6       Dove                    NaN       P234
# 7      Pepsi                    NaN       P345
# 8       Coke                    NaN       P700

# %%
product_details.combine_first(brand_details)
# Out:
#   Brand Name            Description Product Id
# 0       Nike     Nike Running Shoes       P123
# 1       Dove           Dove Shampoo       P234
# 2      Pepsi  Pepsi 16OZ. Diet Coke       P345
# 3       Coke  Good furniture chairs       P999
# 4        NaN         Confort sheets       P567

# %%
brand_details.combine_first(product_details) # if the value is Null in first dataframe then picks up the value from the second dataframe
# Out:
#   Brand Name            Description Product Id
# 0       Nike     Nike Running Shoes       P123
# 1       Dove           Dove Shampoo       P234
# 2      Pepsi  Pepsi 16OZ. Diet Coke       P345
# 3       Coke  Good furniture chairs       P700
# 4        NaN         Confort sheets       P567

# %%
df_st = order_details.stack()

# %%
df_st
# Out:
# 0  Order No.      1.00
#    Order Amt    100.00
# 1  Order No.      2.00
#    Order Amt     56.99
# dtype: float64

# %%
order_details
# Out:
#    Order No.  Order Amt
# 0          1     100.00
# 1          2      56.99

# %%
df_st.unstack()
# Out:
#    Order No.  Order Amt
# 0        1.0     100.00
# 1        2.0      56.99

# %%
#pivoting DataFrame
titanic = pd.read_csv('titanic.csv')
titanic=titanic.drop_duplicates()
titanic.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
titanic_pivot = titanic.pivot("Sex", "PassengerId")

# %%
titanic_pivot
# Out:
# PassengerId  892   893   894   895   896   897   898   899   900   901   ...   \
# Sex                                                                      ...
# female        NaN   3.0   NaN   NaN   3.0   NaN   3.0   NaN   3.0   NaN  ...
# male          3.0   NaN   2.0   3.0   NaN   3.0   NaN   2.0   NaN   3.0  ...
#
# PassengerId  1300  1301  1302  1303  1304  1305  1306  1307  1308  1309
# Sex
# female        3.0   3.0   3.0   1.0   3.0   NaN   1.0   NaN   NaN   NaN
# male          NaN   NaN   NaN   NaN   NaN   3.0   NaN   3.0   3.0   3.0
#
# [2 rows x 418 columns]

# %%
country= pd.read_clipboard()
country
# Out:
#    Country       Region  Happiness       Rank Happiness.1    Score  Economy  \
# 0      141  Switzerland    Western     Europe         1.0    7.587  1.39651
# 1       60      Iceland    Western     Europe         2.0    7.561  1.30232
# 2       38      Denmark    Western     Europe         3.0    7.527  1.32548
# 3      108       Norway    Western     Europe         4.0    7.522  1.45900
# 4       25       Canada      North    America         5.0    7.427  1.32629
# 5       46      Finland    Western     Europe         6.0    7.406  1.29025
# 6      102  Netherlands    Western     Europe         7.0    7.378  1.32944
# 7      140       Sweden    Western     Europe         8.0    7.364  1.33171
# 8      103          New    Zealand  Australia         and      New  Zealand
# 9        6    Australia  Australia        and         New  Zealand     10.0
#
#       (GDP      per  Capita)  ...     (Life  Expectancy)  Freedom       Trust  \
# ...

# %%
country_pv = country.pivot("Region","Happiness","Score")

# %%
country.rename(index={0:'Switzerland'},
              columns={'Happiness':'Directions'})
# Out:
#              Country       Region Directions       Rank Happiness.1    Score  \
# Switzerland      141  Switzerland    Western     Europe         1.0    7.587
# 1                 60      Iceland    Western     Europe         2.0    7.561
# 2                 38      Denmark    Western     Europe         3.0    7.527
# 3                108       Norway    Western     Europe         4.0    7.522
# 4                 25       Canada      North    America         5.0    7.427
# 5                 46      Finland    Western     Europe         6.0    7.406
# 6                102  Netherlands    Western     Europe         7.0    7.378
# 7                140       Sweden    Western     Europe         8.0    7.364
# 8                103          New    Zealand  Australia         and      New
# 9                  6    Australia  Australia        and         New  Zealand
#
#              Economy     (GDP      per  Capita)  ...     (Life  Expectancy)  \
# ...

# %%
country.rename(index={0:'Switzerland'},
              columns={'Happiness':'Directions'}, inplace=True)

# %%
country
# Out:
#              Country       Region Directions       Rank Happiness.1    Score  \
# Switzerland      141  Switzerland    Western     Europe         1.0    7.587
# 1                 60      Iceland    Western     Europe         2.0    7.561
# 2                 38      Denmark    Western     Europe         3.0    7.527
# 3                108       Norway    Western     Europe         4.0    7.522
# 4                 25       Canada      North    America         5.0    7.427
# 5                 46      Finland    Western     Europe         6.0    7.406
# 6                102  Netherlands    Western     Europe         7.0    7.378
# 7                140       Sweden    Western     Europe         8.0    7.364
# 8                103          New    Zealand  Australia         and      New
# 9                  6    Australia  Australia        and         New  Zealand
#
#              Economy     (GDP      per  Capita)  ...     (Life  Expectancy)  \
# ...

# %%
#binning
age_bins=[10,20,30,40,50,60,70,80]
age = titanic['Age']

titanic_age = pd.cut(age, age_bins)

# %%
pd.value_counts(titanic_age)  # counts of different Ages in titanic dataste for each Age bin
# Out:
# (20, 30]    131
# (30, 40]     55
# (10, 20]     47
# (40, 50]     46
# (50, 60]     20
# (60, 70]     10
# (70, 80]      1
# Name: Age, dtype: int64

# %%
# Finding Outliers
titanic.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
titanic_curated = titanic[titanic['Age']<80]  # get all rows where Age <80

# %%
titanic_curated  = titanic_curated[titanic_curated['Cabin'].isnull() == False]  # get all rows where  Cabin is not Null
titanic_curated
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# 34           926       1                           Mock, Mr. Philipp Edmund
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 50           942       1                           Smith, Mr. Lucien Philip
# 53           945       1                         Fortune, Miss. Ethel Flora
# ...
